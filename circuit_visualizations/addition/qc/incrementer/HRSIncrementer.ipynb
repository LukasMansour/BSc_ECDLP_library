# %%
from api.CircuitChooser import CircuitChooser
from api.NameFilters import custom_name_filter

# %%
CircuitChooser()._name_filter = custom_name_filter({"HRSIncrementer"})
CircuitChooser().choose_component("QCIncrementer", (4, 0, 0), dirty_available=4, clean_available=0).get_circuit().draw(
    output='mpl')

# %%
CircuitChooser().clear_caches()
CircuitChooser()._name_filter = custom_name_filter({"HRSIncrementer"})
CircuitChooser().choose_component("QCIncrementer", (4, 1, 0), dirty_available=2,
                                  clean_available=0).get_circuit().decompose().draw(output='mpl')
