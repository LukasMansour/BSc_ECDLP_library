# %%
from api.CircuitChooser import CircuitChooser
from api.NameFilters import custom_name_filter

# %%
CircuitChooser()._name_filter = custom_name_filter({"GidneyIncrementer"})
CircuitChooser().choose_component("QCIncrementer", (4, 0, 0), dirty_available=5, clean_available=0).get_circuit().draw(
    output='mpl')

# %%
CircuitChooser().clear_caches()
CircuitChooser().choose_component("QCIncrementer", (4, 0, 0), dirty_available=4, clean_available=1).get_circuit().draw(
    output='mpl')

# %%
CircuitChooser().clear_caches()
CircuitChooser().choose_component("QCIncrementer", (4, 1, 0), dirty_available=4, clean_available=0).get_circuit().draw(
    output='mpl')
