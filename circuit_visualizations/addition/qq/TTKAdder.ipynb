# %%
from api.CircuitChooser import CircuitChooser
from api.NameFilters import custom_name_filter

# %%
CircuitChooser()._name_filter = custom_name_filter({"TTKAdderIP"})
CircuitChooser().choose_component("QQAdderIP", (4, 0), dirty_available=0, clean_available=0).get_circuit().draw(
    output='mpl')

# %%
CircuitChooser().clear_caches()
CircuitChooser()._name_filter = custom_name_filter({"TTKAdderIP"})
CircuitChooser().choose_component("QQAdderIP", (5, 1), dirty_available=0, clean_available=0).get_circuit().draw(
    output='mpl')
