# %%
from api.CircuitChooser import CircuitChooser
from api.NameFilters import custom_name_filter

# %%
CircuitChooser()._name_filter = custom_name_filter(
    {"RNSLModularNegationIP", "BasicIncrementer", "BasicConstantAdderIP"})
CircuitChooser().choose_component("QCModularNegationIP", (4, 7, 0), dirty_available=0,
                                  clean_available=1).get_circuit().draw(output='mpl')
