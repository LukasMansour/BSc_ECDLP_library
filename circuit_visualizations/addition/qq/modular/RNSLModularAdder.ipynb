# %%
from api.CircuitChooser import CircuitChooser
from api.NameFilters import custom_name_filter

# %%
CircuitChooser()._name_filter = custom_name_filter(
    {"RNSLModularAdderIP", "CDKMAdderIP", "CDKMComparator", "HRSComparator", "HRSIncrementer", "HRSConstantAdderIP"})
CircuitChooser().choose_component("QQModAdderIP", (4, 7, 0), dirty_available=0, clean_available=2).get_circuit().draw(
    output='mpl')
