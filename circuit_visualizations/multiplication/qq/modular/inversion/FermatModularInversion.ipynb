# %%
from api.CircuitChooser import CircuitChooser

# %%
CircuitChooser().choose_component("QQModInversionOOP", (4, 11, 0), dirty_available=1,
                                  clean_available=2).get_circuit().draw(
    output='mpl')
