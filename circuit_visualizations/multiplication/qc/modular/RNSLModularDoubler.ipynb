# %%
from api.CircuitChooser import CircuitChooser
from api.NameFilters import custom_name_filter

# %%
CircuitChooser()._name_filter = custom_name_filter(
    {"RNSLModularDoublerIP", "CDKMAdderIP", "CDKMComparator", "HRSComparator", "BasicIncrementer",
     "BasicConstantAdderIP", "TTKAdderIP"})
CircuitChooser().choose_component("QCModDoublerIP", (4, 7, 0), dirty_available=0, clean_available=4).get_circuit().draw(
    output='mpl')

# %%
CircuitChooser()._name_filter = custom_name_filter(
    {"RNSLModularDoublerIP", "CDKMAdderIP", "CDKMComparator", "HRSComparator", "BasicIncrementer",
     "BasicConstantAdderIP", "TTKAdderIP"})
CircuitChooser().choose_component("QCModDoublerIP", (4, 7, 1), dirty_available=0, clean_available=1).get_circuit().draw(
    output='mpl')
