# %%
from api.CircuitChooser import CircuitChooser
from api.NameFilters import custom_name_filter

# %%
CircuitChooser()._name_filter = custom_name_filter(
    {"RCConstantModularMultiplierOOP", "CDKMAdderIP", "CDKMComparator", "HRSComparator", "BasicIncrementer",
     "BasicConstantAdderIP", "TTKAdderIP"})
CircuitChooser().choose_component("QCModMulOOP", (4, 6, 7, 0), dirty_available=0, clean_available=2).get_circuit().draw(
    output='mpl')
